# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression 
from sklearn.svm import SVC 
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.tree import plot_tree
import joblib

# %% [markdown]
# # Data Representation

# %%
df = pd.read_csv("F:\Atomika\Machine Learning\8- session-8\Customer Churn Prediction\Dataset\Churn_Modelling.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\elmnshawy\AppData\Local\Temp\ipykernel_14276\2313968834.py:1: SyntaxWarning: invalid escape sequence '\A'
#   df = pd.read_csv("F:\Atomika\Machine Learning\8- session-8\Customer Churn Prediction\Dataset\Churn_Modelling.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave        619.0    France  Female   42
# 1          2    15647311      Hill        608.0     Spain     NaN   41
# 2          3    15619304      Onio        502.0    France  Female   42
# 3          4    15701354      Boni        699.0    France  Female   39
# 4          5    15737888  Mitchell        850.0     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.tail()
# Out:
#        RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 9999       10000    15628319      Walker        792.0    France  Female   28
# 10000         51    15616550  Chidiebele        698.0   Germany    Male   44
# 10001        122    15580203     Kennedy        674.0     Spain    Male   39
# 10002        129    15575492     Kennedy        828.0    France  Female   41
# 10003        401    15690452        Tung        605.0    France    Male   52
#
#        Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9999        4  130142.79              1          1               0
# 10000      10  116363.37              2          1               0
# 10001       6  120193.42              1          0               0
# 10002       7       0.00              2          1               0
# 10003       1   63349.75              1          1               0
#
#        EstimatedSalary  Exited
# 9999          38190.78       0
# 10000        198059.16       0
# 10001        100130.95       0
# 10002        171378.77       0
# 10003        108887.44       0

# %%
df.sample(7)
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 4244       4245    15684908  Davidson        540.0   Germany    Male   64
# 2082       2083    15617617   Stewart        811.0     Spain    Male   39
# 6594       6595    15808544   Cameron        747.0    France  Female   40
# 8240       8241    15708504      Wong        790.0   Germany    Male   50
# 1920       1921    15723720  McKenzie        591.0    France  Female   31
# 3710       3711    15601796  Chizuoke        645.0    France    Male   30
# 484         485    15676519    George        615.0     Spain    Male   61
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 4244       1   91869.69              1          0               1
# 2082       7       0.00              2          1               1
# 6594       3       0.00              1          0               0
# 8240       8  121438.58              1          1               1
# 1920       7       0.00              2          0               1
# 3710       1  125739.26              1          1               1
# 484        9       0.00              2          1               0
#
#       EstimatedSalary  Exited
# 4244         95421.00       0
# 2082        177519.39       0
# 6594         57817.84       1
# 8240        176471.78       1
# 1920         48778.46       0
# 3710        193441.23       0
# 484         150227.85       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10004 entries, 0 to 10003
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10004 non-null  int64
#  1   CustomerId       10004 non-null  int64
#  2   Surname          10004 non-null  object
#  3   CreditScore      9998 non-null   float64
#  4   Geography        10004 non-null  object
#  5   Gender           10003 non-null  object
#  6   Age              10004 non-null  int64
#  7   Tenure           10004 non-null  int64
#  8   Balance          10004 non-null  float64
#  9   NumOfProducts    10004 non-null  int64
#  10  HasCrCard        10004 non-null  int64
#  11  IsActiveMember   10004 non-null  int64
#  12  EstimatedSalary  10004 non-null  float64
#  13  Exited           10004 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#           RowNumber    CustomerId  CreditScore           Age        Tenure  \
# count  10004.000000  1.000400e+04  9998.000000  10004.000000  10004.000000
# mean    4998.570872  1.569091e+07   650.609322     38.923830      5.013195
# std     2887.931077  7.194342e+04    96.639950     10.486668      2.892389
# min        1.000000  1.556570e+07   350.000000     18.000000      0.000000
# 25%     2497.750000  1.562839e+07   584.000000     32.000000      3.000000
# 50%     4998.500000  1.569071e+07   652.000000     37.000000      5.000000
# 75%     7499.250000  1.575322e+07   718.000000     44.000000      7.000000
# max    10000.000000  1.581569e+07   850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts     HasCrCard  IsActiveMember  \
# count   10004.000000   10004.000000  10004.000000    10004.000000
# mean    76485.285828       1.530188      0.705518        0.514894
# std     62392.558080       0.581624      0.455832        0.499803
# min         0.000000       1.000000      0.000000        0.000000
# 25%         0.000000       1.000000      0.000000        0.000000
# 50%     97198.540000       1.000000      1.000000        1.000000
# 75%    127639.372500       2.000000      1.000000        1.000000
# max    250898.090000       4.000000      1.000000        1.000000
#
#        EstimatedSalary        Exited
# count     10004.000000  10004.000000
# mean     100108.042296      0.203619
# std       57511.817692      0.402709
# min          11.580000      0.000000
# 25%       51014.837500      0.000000
# 50%      100218.210000      0.000000
# 75%      149400.107500      0.000000
# max      199992.480000      1.000000

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### clear null values

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        6
# Geography          0
# Gender             1
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df['CreditScore'] = df['CreditScore'].fillna(df['CreditScore'].mean())

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ### check duplicated values

# %%
df.duplicated().sum()
# Out:
# 4

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# ### Drop Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  float64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
df = df.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0        619.0    France  Female   42       2       0.00              1
# 1        608.0     Spain    Male   41       1   83807.86              1
# 2        502.0    France  Female   42       8  159660.80              3
# 3        699.0    France  Female   39       1       0.00              2
# 4        850.0     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# # EDA

# %%
df['CreditScore'].describe()
# Out:
# count    10000.000000
# mean       650.589066
# std         96.611475
# min        350.000000
# 25%        584.000000
# 50%        652.000000
# 75%        718.000000
# max        850.000000
# Name: CreditScore, dtype: float64

# %%
df['CreditScore'].hist()
# Out:
# <Axes: >

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0           619.0    France  Female   42       2       0.00              1
# 1           608.0     Spain    Male   41       1   83807.86              1
# 2           502.0    France  Female   42       8  159660.80              3
# 3           699.0    France  Female   39       1       0.00              2
# 4           850.0     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995        771.0    France    Male   39       5       0.00              2
# 9996        516.0    France    Male   35      10   57369.61              1
# 9997        709.0    France  Female   36       7       0.00              1
# 9998        772.0   Germany    Male   42       3   75075.31              2
# 9999        792.0    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
plt.figure(figsize=(6,5))
sns.set_palette("muted")  
sns.countplot(x='Geography', data=df)
plt.title("Geography")
plt.xlabel("Country")
plt.ylabel("Count")
plt.xticks(rotation=25)  
plt.tight_layout()
plt.show()

# %%
df['Geography'].value_counts(normalize=True) * 100
# Out:
# Geography
# France     50.14
# Germany    25.09
# Spain      24.77
# Name: proportion, dtype: float64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5458
# Female    4542
# Name: count, dtype: int64

# %%
df[df['Balance'] == 0]
# Out:
#       CreditScore Geography  Gender  Age  Tenure  Balance  NumOfProducts  \
# 0      619.000000    France  Female   42       2      0.0              1
# 3      699.000000    France  Female   39       1      0.0              2
# 6      822.000000    France    Male   50       7      0.0              2
# 11     650.609322     Spain    Male   24       3      0.0              2
# 12     650.609322    France  Female   34      10      0.0              2
# ...           ...       ...     ...  ...     ...      ...            ...
# 9989   841.000000     Spain    Male   28       4      0.0              2
# 9992   726.000000     Spain    Male   36       2      0.0              1
# 9994   800.000000    France  Female   29       2      0.0              2
# 9995   771.000000    France    Male   39       5      0.0              2
# 9997   709.000000    France  Female   36       7      0.0              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 3             0               0         93826.63       0
# 6             1               1         10062.80       0
# 11            1               0         76390.01       0
# 12            1               0         26260.98       0
# ...         ...             ...              ...     ...
# 9989          1               1        179436.60       0
# 9992          1               0        195192.40       0
# 9994          0               0        167773.55       0
# 9995          1               0         96270.64       0
# 9997          0               1         42085.58       1
#
# [3617 rows x 11 columns]

# %%
plt.figure(figsize=(8, 5))
df['Balance'].hist(bins=30, color='skyblue', edgecolor='black')
plt.title("Balance Distribution")
plt.xlabel("Balance")
plt.ylabel("Frequency")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
df['Age'].hist(bins=30, color='skyblue', edgecolor='black')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0        619.0    France  Female   42       2       0.00              1
# 1        608.0     Spain    Male   41       1   83807.86              1
# 2        502.0    France  Female   42       8  159660.80              3
# 3        699.0    France  Female   39       1       0.00              2
# 4        850.0     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df['IsActiveMember'].value_counts()
# Out:
# IsActiveMember
# 1    5151
# 0    4849
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['EstimatedSalary'], bins=30, kde=True, color='skyblue', edgecolor='black')
plt.title("Estimated Salary Distribution")
plt.xlabel("Estimated Salary")
plt.ylabel("Density")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
churn_counts = df['Exited'].value_counts()
print(churn_counts)
plt.figure(figsize=(5, 5))
plt.pie(churn_counts, labels=['Stayed', 'Exited'], autopct='%1.1f%%', colors=['skyblue', 'salmon'], startangle=90)
plt.title('Customer Churn Distribution')
plt.axis('equal')  # Make it a circle
plt.show()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
palette_colors = ['skyblue', 'lightgreen', 'salmon']  # Example for 3 categories

sns.countplot(x='Exited', hue='Geography', data=df, palette=palette_colors)
plt.title("Exited Count by Geography")
plt.xlabel("Exited")
plt.ylabel("Count")
plt.legend(title='Geography')
plt.tight_layout()
plt.show()

# %%
sns.lmplot(x='Balance' ,y='EstimatedSalary' , data=df.sample(500))

# %%
df.groupby(['Exited'])['IsActiveMember'].value_counts()
# Out:
# Exited  IsActiveMember
# 0       1                 4416
#         0                 3547
# 1       0                 1302
#         1                  735
# Name: count, dtype: int64

# %%
grouped = df.groupby(['Exited', 'IsActiveMember']).size().reset_index(name='Count')
plt.figure(figsize=(8, 5))
sns.barplot(data=grouped, x='Exited', y='Count', hue='IsActiveMember', palette='muted')
plt.title("Active Membership by Churn (Exited)")
plt.xlabel("Exited (0 = Stayed, 1 = Exited)")
plt.ylabel("Number of Customers")
plt.legend(title='Is Active Member')
plt.tight_layout()
plt.show()

# %%
x = df.drop('Exited' , axis=1)
y = df['Exited']

# %%
x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0           619.0    France  Female   42       2       0.00              1
# 1           608.0     Spain    Male   41       1   83807.86              1
# 2           502.0    France  Female   42       8  159660.80              3
# 3           699.0    France  Female   39       1       0.00              2
# 4           850.0     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995        771.0    France    Male   39       5       0.00              2
# 9996        516.0    France    Male   35      10   57369.61              1
# 9997        709.0    France  Female   36       7       0.00              1
# 9998        772.0   Germany    Male   42       3   75075.31              2
# 9999        792.0    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %% [markdown]
# #### Encode Data

# %%
geography = LabelEncoder()
x['Geography'] = geography.fit_transform(x['Geography'])
gender = LabelEncoder()
x['Gender'] = gender.fit_transform(x['Gender'])

# %%
mapping = dict(zip(geography.classes_, range(len(geography.classes_))))
print("Mapping:", mapping)
# Out:
# Mapping: {'France': 0, 'Germany': 1, 'Spain': 2}

# %%
mapping = dict(zip(gender.classes_, range(len(gender.classes_))))
print("Mapping:", mapping)
# Out:
# Mapping: {'Female': 0, 'Male': 1}

# %%
x.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0        619.0          0       0   42       2       0.00              1
# 1        608.0          2       1   41       1   83807.86              1
# 2        502.0          0       0   42       8  159660.80              3
# 3        699.0          0       0   39       1       0.00              2
# 4        850.0          2       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %% [markdown]
# #### Split data

# %%
xtrain , xtest ,ytrain , ytest = train_test_split(x,y , test_size=.2 , random_state=27)

# %% [markdown]
# #### Normalize data

# %%
scaler = MinMaxScaler()
x_train_scaled = scaler.fit_transform(xtrain)
x_test_scaled  = scaler.transform(xtest)

# %%
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
x_test_scaled[0]
# Out:
# array([0.694     , 0.        , 0.        , 0.39189189, 0.6       ,
#        0.53800064, 0.        , 1.        , 1.        , 0.84028935])

# %% [markdown]
# ## Modeling

# %% [markdown]
# #### Logistic Regression

# %%
logistic_model = LogisticRegression()
logistic_model.fit(x_train_scaled , ytrain)
# Out:
# LogisticRegression()

# %%
logistic_model.predict(x_test_scaled)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_predict = logistic_model.predict(x_test_scaled)
y_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
print('Logistic regression accuracy : ',accuracy_score(ytest , y_predict))
# Out:
# Logistic regression accuracy :  0.809

# %%
ConfusionMatrixDisplay.from_estimator(logistic_model, x_test_scaled, ytest, cmap='Blues')
plt.show()

# %% [markdown]
# #### SVM model

# %%
svc = SVC(kernel='rbf' ,C=2)
svc.fit(x_train_scaled , ytrain)
# Out:
# SVC(C=2)

# %%
y_predict = svc.predict(x_test_scaled)

# %%
print('svm accuracy : ' , accuracy_score(ytest , y_predict))
# Out:
# svm accuracy :  0.862

# %%
ConfusionMatrixDisplay.from_estimator(svc , x_test_scaled , ytest , cmap='Blues')

# %% [markdown]
# #### Random forest model

# %%
random_forest_model = RandomForestClassifier(n_estimators=120)
random_forest_model.fit(x_train_scaled , ytrain)
# Out:
# RandomForestClassifier(n_estimators=120)

# %%
y_predict = random_forest_model.predict(x_test_scaled)

# %%
print('svm accuracy : ' , accuracy_score(ytest , y_predict))
# Out:
# svm accuracy :  0.8665

# %%
plt.figure(figsize=(20, 5))
plot_tree(random_forest_model.estimators_[0], 
          feature_names=xtrain.columns, 
          class_names=["Class 0", "Class 1"],
          filled=True, 
          rounded=True, 
          max_depth=3)  # لو عايز الشجرة تكون أوضح
plt.title("Random Forest - One Tree Visualization")
plt.show()

# %% [markdown]
# ## save random forest model

# %%
joblib.dump(random_forest_model, 'rf_churn_prediction86_v1.pkl')
# Out:
# ['rf_churn_prediction86_v1.pkl']
